# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import time
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL 
query_url = f'{url}appid={weather_api_key}&units={units}&q='


# set up lists to hold reponse info
name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []


#Set variables for counters
record = 1
set = 1

#Print the beginning statement
print("Beginning Data Retrieval ")
print("-----------------------------")

# Make a request for each of the cities in the list
for city in cities:
    response = requests.get(query_url + city).json()
    
    #Pull data for each category, using try and except for cities that aren't found
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        #If data is stored, print record name of sets of 50 and city name
        print(f'Processing Record {record} of Set {set} | {city}')
        
        #Add one to the counter of the records
        record = record + 1
        
        #If the record number goes over 50, start a new set
        if record > 50:
              record = 1
              set = set + 1
            
    #If there is a key error with the city name, print that this city is skipped
    except(KeyError):
        print(f'City not found. Skipping...')
        
#Print the ending statements
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | alofi
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | buala
# Processing Record 5 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | konstantinovka
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | chupa
# Processing Record 13 of Set 1 | kununurra
# Processing Record 14 of Set 1 | moose factory
# City not found. Skipping...
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | bobo dioulasso
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | ler
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | port elizabeth
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Put collected data into a dataframe
city_df = pd.DataFrame({"City": name, "Latitude": lat, "Longitude": lng, "Max Temp": max_temp, "Humidity": humidity,
                       "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": country, "Date": date})

#Export data to csv
city_df.to_csv("output_files/city.csv")

city_df.head()
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0       Albany   42.6001   -73.9662      23.0        50          99
# 1        Alofi  -19.0595  -169.9187      75.2       100          90
# 2  Tuktoyaktuk   69.4541  -133.0374     -20.2        76          90
# 3        Buala   -8.1450   159.5921      81.1        78         100
# 4  Yellowknife   62.4560  -114.3525      -4.0        77          75
#
#    Wind Speed Country        Date
# 0        1.01      US  1612199914
# 1        4.61      NU  1612200185
# 2        5.75      CA  1612200185
# 3       13.87      SB  1612200185
# 4        8.05      CA  1612199896

# %%
too_humid = city_df["Humidity"].loc[city_df["Humidity"]>100]
print(too_humid)
# Out:
# Series([], Name: Humidity, dtype: int64)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
too_humid = city_df["Humidity"].loc[city_df["Humidity"]>100]
# print(too_humid["index"])
print(too_humid)
# Out:
# Series([], Name: Humidity, dtype: int64)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Max Temp"], marker="o", edgecolor = "black")

# Incorporate the other graph properties
plt.title(f'Max Temperature vs City Latitude ({date_convert})')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Humidity"], marker="o", edgecolor = "black")

# Incorporate the other graph properties
plt.title(f'Humidity vs City Latitude ({date_convert})')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Cloudiness"], marker="o", edgecolor = "black")

# Incorporate the other graph properties
plt.title(f'Cloudiness vs City Latitude ({date_convert})')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Wind Speed"], marker="o", edgecolor = "black")

# Incorporate the other graph properties
plt.title(f'Wind Speed vs City Latitude ({date_convert})')
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Create separate dfs for Northern & Southern Hemispheres
northern_lat_df = city_df.loc[city_df["Latitude"] >= 0]
southern_lat_df = city_df.loc[city_df["Latitude"] < 0]
# Out:
#                 City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 1              Alofi  -19.0595  -169.9187     75.20       100          90
# 3              Buala   -8.1450   159.5921     81.10        78         100
# 7        Port Alfred  -33.5906    26.8910     66.99        70          75
# 8            Ushuaia  -54.8000   -68.3000     51.80        71          20
# 9              Airai   -8.9266   125.4092     61.59       100          99
# ..               ...       ...        ...       ...       ...         ...
# 523           Albury  -36.0833   146.9167     62.60       100          75
# 532       Launceston  -41.4500   147.1667     53.01        81          16
# 533            Rundu  -17.9333    19.7667     71.98        85          92
# 534  Rodrigues Alves   -7.7380   -72.6509     89.60        62          75
# 538           Padang   -0.9492   100.3543     75.20        94          40
#
#      Wind Speed Country        Date
# 1          4.61      NU  1612200185
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_lat_df["Latitude"], northern_lat_df["Max Temp"])

# Get regression values
regress_values = northern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(northern_lat_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(northern_lat_df["Latitude"], northern_lat_df["Max Temp"], marker="o", edgecolor = "black")
plt.plot(northern_lat_df["Latitude"],regress_values,"r-")

# Incorporate the other graph properties
plt.title(f'Northern Hemisphere: Max Temperature vs City Latitude ({date_convert})')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")


#Annotate the line equation
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig5.png")

# Show plot
plt.show()
# Out:
# The r-value is: -0.8566857621127999

# %% [markdown]
# There is a strong negative correlation between the maximum temperature and latitude of cities in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_lat_df["Latitude"], southern_lat_df["Max Temp"])

# Get regression values
regress_values_2 = southern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_2 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(southern_lat_df['Date'][1])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(southern_lat_df["Latitude"], southern_lat_df["Max Temp"], marker="o", edgecolor = "black")
plt.plot(southern_lat_df["Latitude"],regress_values_2,"r-")

# Incorporate the other graph properties
plt.title(f'Southern Hemisphere: Max Temperature vs City Latitude ({date_convert})')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")

#Annotate the line equation
plt.annotate(line_eq_2,(-55, 90),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig6.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.5936200766149775

# %% [markdown]
# There is a moderate positive correlation between the maximum temperature and latitude of cities in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_lat_df["Latitude"], northern_lat_df["Humidity"])

# Get regression values
regress_values_3 = northern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_3 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(northern_lat_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(northern_lat_df["Latitude"], northern_lat_df["Humidity"], marker="o", edgecolor = "black")
plt.plot(northern_lat_df["Latitude"],regress_values_3,"r-")

# Incorporate the other graph properties
plt.title(f'Northern Hemisphere: Humidity vs City Latitude ({date_convert})')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")


#Annotate the line equation
plt.annotate(line_eq_3,(45,25),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig7.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.40432964665626697

# %% [markdown]
# There is a slight positive correlation between humidity and latitude for cities in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_lat_df["Latitude"], southern_lat_df["Humidity"])

# Get regression values
regress_values_4 = southern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_4 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(southern_lat_df['Date'][1])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(southern_lat_df["Latitude"], southern_lat_df["Humidity"], marker="o", edgecolor = "black")
plt.plot(southern_lat_df["Latitude"],regress_values_4,"r-")

# Incorporate the other graph properties
plt.title(f'Southern Hemisphere: Max Temperature vs City Latitude ({date_convert})')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")



#Annotate the line equation
plt.annotate(line_eq_4,(-55, 45),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig8.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.11650364746351931

# %% [markdown]
# The correlation between maximum temperature and latitude is negligible for cities in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_lat_df["Latitude"], northern_lat_df["Cloudiness"])

# Get regression values
regress_values_5 = northern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_5 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(northern_lat_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(northern_lat_df["Latitude"], northern_lat_df["Cloudiness"], marker="o", edgecolor = "black")
plt.plot(northern_lat_df["Latitude"],regress_values_5,"r-")

# Incorporate the other graph properties
plt.title(f'Northern Hemisphere: Cloudiness vs City Latitude ({date_convert})')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")


#Annotate the line equation
plt.annotate(line_eq_5,(20,65),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig9.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.35049864877704473

# %% [markdown]
# There is a slight positive correlation between cloudiness and latitude for cities in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_lat_df["Latitude"], southern_lat_df["Cloudiness"])

# Get regression values
regress_values_6 = southern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_6 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(southern_lat_df['Date'][1])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(southern_lat_df["Latitude"], southern_lat_df["Cloudiness"], marker="o", edgecolor = "black")
plt.plot(southern_lat_df["Latitude"],regress_values_6,"r-")

# Incorporate the other graph properties
plt.title(f'Southern Hemisphere: Cloudiness vs City Latitude ({date_convert})')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")



#Annotate the line equation
plt.annotate(line_eq_6,(-55, 45),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig10.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.3824492810406366

# %% [markdown]
# There is a weak positive correlation between cloudiness and latitude for cities in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Perform linear regression on temp vs latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_lat_df["Latitude"], northern_lat_df["Wind Speed"])

# Get regression values
regress_values_7 = northern_lat_df["Latitude"] * slope + intercept

# Create line equation string
line_eq_7 = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


#Convert the date
date_time = time.gmtime(northern_lat_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(northern_lat_df["Latitude"], northern_lat_df["Wind Speed"], marker="o", edgecolor = "black")
plt.plot(northern_lat_df["Latitude"],regress_values_7,"r-")

# Incorporate the other graph properties
plt.title(f'Northern Hemisphere: Wind Speed vs City Latitude ({date_convert})')
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")


#Annotate the line equation
plt.annotate(line_eq_7,(0,30),fontsize=15,color="red")

# Print r value - should this be r2 or just r???
# print(f"The r-value is: {rvalue**2}")
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_files/fig11.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.03427239843358787

# %% [markdown]
# The correlation between wind speed and latitude for cities in the Northern Hemisphere is negligible.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
