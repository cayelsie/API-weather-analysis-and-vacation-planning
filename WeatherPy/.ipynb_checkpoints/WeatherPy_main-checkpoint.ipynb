# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import time

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL 
query_url = f'{url}appid={weather_api_key}&{units}&q='


# set up lists to hold reponse info
name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []


#Set variables for counters
record = 1
set = 1

#Print the beginning statement
print("Beginning Data Retrieval ")
print("-----------------------------")

# Make a request for each of the cities in the list
for city in cities:
    response = requests.get(query_url + city).json()
    
    #Pull data for each category, using try and except for cities that aren't found
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        #If data is stored, print record name of sets of 50 and city name
        print(f'Processing Record {record} of Set {set} | {city}')
        
        #Add one to the counter of the records
        record = record + 1
        
        #If the record number goes over 50, start a new set
        if record > 50:
              record = 1
              set = set + 1
            
    #If there is a key error with the city name, print that this city is skipped
    except(KeyError):
        print(f'City not found. Skipping...')
        
#Print the ending statements
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hualmay
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | srednekolymsk
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | verkhnevilyuysk
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | porangatu
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | kulhudhuffushi
# Processing Record 14 of Set 1 | lasa
# City not found. Skipping...
# Processing Record 15 of Set 1 | mikhaylovka
# Processing Record 16 of Set 1 | boa vista
# Processing Record 17 of Set 1 | port-cartier
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | tura
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | bandarbeyla
# Processing Record 23 of Set 1 | yerofey pavlovich
# Processing Record 24 of Set 1 | lata
# Processing Record 25 of Set 1 | marawi
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | nantucket
# City not found. Skipping...
# Processing Record 29 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 30 of Set 1 | west plains
# Processing Record 31 of Set 1 | alpena
# Processing Record 32 of Set 1 | nouakchott
# Processing Record 33 of Set 1 | nawa
# Processing Record 34 of Set 1 | yar-sale
# Processing Record 35 of Set 1 | vila velha
# Processing Record 36 of Set 1 | phan thiet
# Processing Record 37 of Set 1 | port macquarie
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | mirabad
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | hofn
# Processing Record 43 of Set 1 | curuguaty
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | poum
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | rocha
# City not found. Skipping...
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | zhigansk
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | bonthe
# Processing Record 7 of Set 2 | kalmunai
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | ixtapa
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | shumskiy
# Processing Record 13 of Set 2 | faanui
# City not found. Skipping...
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | high rock
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | novoaleksandrovsk
# Processing Record 18 of Set 2 | kaeo
# Processing Record 19 of Set 2 | vila do maio
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | chapleau
# Processing Record 23 of Set 2 | salta
# Processing Record 24 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | tuatapere
# Processing Record 27 of Set 2 | salalah
# Processing Record 28 of Set 2 | sombrio
# Processing Record 29 of Set 2 | longyan
# Processing Record 30 of Set 2 | eydhafushi
# Processing Record 31 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 32 of Set 2 | east stroudsburg
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | jiuquan
# Processing Record 35 of Set 2 | azare
# Processing Record 36 of Set 2 | belawan
# Processing Record 37 of Set 2 | poso
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | venice
# Processing Record 40 of Set 2 | mount gambier
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | malanje
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | bonfim
# Processing Record 46 of Set 2 | ust-charyshskaya pristan
# Processing Record 47 of Set 2 | ellsworth
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | serenje
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | nemuro
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | prince rupert
# Processing Record 6 of Set 3 | dikson
# City not found. Skipping...
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | alugan
# Processing Record 11 of Set 3 | tyulgan
# Processing Record 12 of Set 3 | manggar
# Processing Record 13 of Set 3 | kaniama
# Processing Record 14 of Set 3 | havre-saint-pierre
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | port augusta
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | traverse city
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | mobile
# Processing Record 21 of Set 3 | yumen
# Processing Record 22 of Set 3 | nishihara
# Processing Record 23 of Set 3 | sur
# Processing Record 24 of Set 3 | pochutla
# City not found. Skipping...
# Processing Record 25 of Set 3 | sioux lookout
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | launceston
# Processing Record 28 of Set 3 | qiongshan
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | saint-augustin
# Processing Record 31 of Set 3 | maldonado
# Processing Record 32 of Set 3 | byron bay
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | inhambane
# Processing Record 35 of Set 3 | samoded
# Processing Record 36 of Set 3 | seoul
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | lodja
# Processing Record 39 of Set 3 | cayenne
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | omboue
# Processing Record 42 of Set 3 | nouadhibou
# Processing Record 43 of Set 3 | ust-tsilma
# Processing Record 44 of Set 3 | ribas do rio pardo
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | flin flon
# Processing Record 47 of Set 3 | miles city
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | yurginskoye
# Processing Record 50 of Set 3 | belaya gora
# Processing Record 1 of Set 4 | mbandaka
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | gabu
# Processing Record 4 of Set 4 | kuusamo
# Processing Record 5 of Set 4 | albanel
# Processing Record 6 of Set 4 | lieksa
# City not found. Skipping...
# Processing Record 7 of Set 4 | akyab
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | northam
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | rexburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | manduria
# Processing Record 13 of Set 4 | sabaudia
# Processing Record 14 of Set 4 | hong gai
# Processing Record 15 of Set 4 | verkhoyansk
# Processing Record 16 of Set 4 | xining
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | rosetta
# Processing Record 21 of Set 4 | saint-philippe
# City not found. Skipping...
# Processing Record 22 of Set 4 | algiers
# Processing Record 23 of Set 4 | la cruz
# Processing Record 24 of Set 4 | hvide sande
# Processing Record 25 of Set 4 | monrovia
# Processing Record 26 of Set 4 | bondeno
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | tecpan
# Processing Record 29 of Set 4 | manga
# Processing Record 30 of Set 4 | kruisfontein
# Processing Record 31 of Set 4 | west wendover
# Processing Record 32 of Set 4 | hirara
# Processing Record 33 of Set 4 | aykhal
# Processing Record 34 of Set 4 | kitimat
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | vostok
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | bilibino
# Processing Record 39 of Set 4 | north bend
# Processing Record 40 of Set 4 | naze
# Processing Record 41 of Set 4 | ossora
# Processing Record 42 of Set 4 | busselton
# Processing Record 43 of Set 4 | esperance
# City not found. Skipping...
# Processing Record 44 of Set 4 | mehamn
# Processing Record 45 of Set 4 | bosaso
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | halifax
# Processing Record 48 of Set 4 | haines junction
# Processing Record 49 of Set 4 | shiyan
# Processing Record 50 of Set 4 | luderitz
# Processing Record 1 of Set 5 | kolaras
# City not found. Skipping...
# Processing Record 2 of Set 5 | te anau
# Processing Record 3 of Set 5 | lorengau
# Processing Record 4 of Set 5 | butaritari
# Processing Record 5 of Set 5 | lagos
# Processing Record 6 of Set 5 | lenger
# Processing Record 7 of Set 5 | tasiilaq
# Processing Record 8 of Set 5 | asosa
# Processing Record 9 of Set 5 | sinnamary
# Processing Record 10 of Set 5 | onega
# Processing Record 11 of Set 5 | paoua
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | olbia
# Processing Record 14 of Set 5 | talaya
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | jalu
# Processing Record 17 of Set 5 | umm lajj
# Processing Record 18 of Set 5 | hovd
# Processing Record 19 of Set 5 | jiujiang
# Processing Record 20 of Set 5 | manokwari
# City not found. Skipping...
# Processing Record 21 of Set 5 | xam nua
# Processing Record 22 of Set 5 | erzin
# Processing Record 23 of Set 5 | ust-maya
# City not found. Skipping...
# Processing Record 24 of Set 5 | gorom-gorom
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | bar harbor
# Processing Record 28 of Set 5 | los llanos de aridane
# Processing Record 29 of Set 5 | balakhta
# Processing Record 30 of Set 5 | nosy varika
# Processing Record 31 of Set 5 | nabire
# City not found. Skipping...
# Processing Record 32 of Set 5 | henties bay
# Processing Record 33 of Set 5 | birjand
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | shitkino
# Processing Record 36 of Set 5 | sola
# Processing Record 37 of Set 5 | yellowknife
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | lagos de moreno
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | aketi
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | cootamundra
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | rincon
# Processing Record 46 of Set 5 | arrifes
# Processing Record 47 of Set 5 | sechura
# City not found. Skipping...
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | challapata
# City not found. Skipping...
# Processing Record 50 of Set 5 | beidao
# Processing Record 1 of Set 6 | mandalgovi
# Processing Record 2 of Set 6 | ulladulla
# Processing Record 3 of Set 6 | boundiali
# Processing Record 4 of Set 6 | waipawa
# Processing Record 5 of Set 6 | kibala
# Processing Record 6 of Set 6 | panama city
# Processing Record 7 of Set 6 | sosnovo-ozerskoye
# Processing Record 8 of Set 6 | pedernales
# Processing Record 9 of Set 6 | zhezkazgan
# Processing Record 10 of Set 6 | tuskegee
# Processing Record 11 of Set 6 | yelizovo
# Processing Record 12 of Set 6 | lubango
# Processing Record 13 of Set 6 | pacific grove
# Processing Record 14 of Set 6 | ahuimanu
# Processing Record 15 of Set 6 | tarauaca
# Processing Record 16 of Set 6 | angoche
# Processing Record 17 of Set 6 | port hardy
# City not found. Skipping...
# Processing Record 18 of Set 6 | tazovskiy
# Processing Record 19 of Set 6 | bayir
# City not found. Skipping...
# Processing Record 20 of Set 6 | garden city
# Processing Record 21 of Set 6 | dawei
# Processing Record 22 of Set 6 | nyiregyhaza
# Processing Record 23 of Set 6 | carupano
# Processing Record 24 of Set 6 | cahors
# Processing Record 25 of Set 6 | pemba
# Processing Record 26 of Set 6 | kungur
# Processing Record 27 of Set 6 | ardakan
# Processing Record 28 of Set 6 | araouane
# Processing Record 29 of Set 6 | grand prairie
# Processing Record 30 of Set 6 | barcelos
# Processing Record 31 of Set 6 | bozova
# Processing Record 32 of Set 6 | ha giang
# Processing Record 33 of Set 6 | ponta do sol
# Processing Record 34 of Set 6 | jinchang
# Processing Record 35 of Set 6 | mangai
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | brainerd
# Processing Record 38 of Set 6 | ginda
# Processing Record 39 of Set 6 | porto novo
# Processing Record 40 of Set 6 | mitsamiouli
# Processing Record 41 of Set 6 | kununurra
# Processing Record 42 of Set 6 | banda aceh
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | chuy
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | isoka
# Processing Record 47 of Set 6 | hambantota
# City not found. Skipping...
# Processing Record 48 of Set 6 | baruun-urt
# Processing Record 49 of Set 6 | solnechnyy
# Processing Record 50 of Set 6 | mareeba
# Processing Record 1 of Set 7 | brownsville
# Processing Record 2 of Set 7 | chernyshevskiy
# Processing Record 3 of Set 7 | barinas
# City not found. Skipping...
# Processing Record 4 of Set 7 | kajaani
# City not found. Skipping...
# Processing Record 5 of Set 7 | hay river
# Processing Record 6 of Set 7 | demba
# Processing Record 7 of Set 7 | dayong
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | karratha
# City not found. Skipping...
# Processing Record 10 of Set 7 | pacifica
# Processing Record 11 of Set 7 | rodrigues alves
# Processing Record 12 of Set 7 | port hawkesbury
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | naryan-mar
# Processing Record 15 of Set 7 | kavieng
# Processing Record 16 of Set 7 | andros town
# Processing Record 17 of Set 7 | sosva
# Processing Record 18 of Set 7 | uyskoye
# Processing Record 19 of Set 7 | harrisburg
# Processing Record 20 of Set 7 | saint-louis
# Processing Record 21 of Set 7 | belomorsk
# Processing Record 22 of Set 7 | poptun
# Processing Record 23 of Set 7 | port hedland
# Processing Record 24 of Set 7 | maningrida
# Processing Record 25 of Set 7 | malakal
# Processing Record 26 of Set 7 | sao filipe
# Processing Record 27 of Set 7 | kodinsk
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | shimoda
# Processing Record 30 of Set 7 | khanpur
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | bengkulu
# Processing Record 33 of Set 7 | yokote
# Processing Record 34 of Set 7 | auki
# Processing Record 35 of Set 7 | boende
# Processing Record 36 of Set 7 | ampanihy
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | dhidhdhoo
# Processing Record 39 of Set 7 | tagusao
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | tibati
# Processing Record 42 of Set 7 | ruteng
# Processing Record 43 of Set 7 | parabel
# Processing Record 44 of Set 7 | nhulunbuy
# Processing Record 45 of Set 7 | aripuana
# Processing Record 46 of Set 7 | nola
# Processing Record 47 of Set 7 | peruibe
# Processing Record 48 of Set 7 | alta floresta
# Processing Record 49 of Set 7 | frederico westphalen
# Processing Record 50 of Set 7 | leshukonskoye
# Processing Record 1 of Set 8 | mirnyy
# Processing Record 2 of Set 8 | balikpapan
# Processing Record 3 of Set 8 | grand gaube
# City not found. Skipping...
# Processing Record 4 of Set 8 | ilebo
# Processing Record 5 of Set 8 | taltal
# Processing Record 6 of Set 8 | veraval
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | nancha
# Processing Record 9 of Set 8 | mwanza
# Processing Record 10 of Set 8 | tashla
# Processing Record 11 of Set 8 | sitka
# City not found. Skipping...
# Processing Record 12 of Set 8 | brest
# Processing Record 13 of Set 8 | pathein
# Processing Record 14 of Set 8 | katsuura
# Processing Record 15 of Set 8 | kushiro
# Processing Record 16 of Set 8 | beatrice
# Processing Record 17 of Set 8 | vao
# Processing Record 18 of Set 8 | buraydah
# Processing Record 19 of Set 8 | gravdal
# Processing Record 20 of Set 8 | litovko
# Processing Record 21 of Set 8 | lhokseumawe
# Processing Record 22 of Set 8 | yuzhno-kurilsk
# Processing Record 23 of Set 8 | sobolevo
# Processing Record 24 of Set 8 | iracoubo
# Processing Record 25 of Set 8 | bairiki
# Processing Record 26 of Set 8 | pachino
# Processing Record 27 of Set 8 | taoudenni
# Processing Record 28 of Set 8 | bereda
# Processing Record 29 of Set 8 | cidreira
# Processing Record 30 of Set 8 | ndele
# Processing Record 31 of Set 8 | gumia
# Processing Record 32 of Set 8 | mountain home
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | kynsperk nad ohri
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | angola
# Processing Record 37 of Set 8 | la ronge
# Processing Record 38 of Set 8 | kaitangata
# Processing Record 39 of Set 8 | kargil
# Processing Record 40 of Set 8 | olafsvik
# Processing Record 41 of Set 8 | hamilton
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | stara synyava
# Processing Record 44 of Set 8 | olinda
# Processing Record 45 of Set 8 | fort frances
# Processing Record 46 of Set 8 | atakpame
# Processing Record 47 of Set 8 | benguela
# Processing Record 48 of Set 8 | ornskoldsvik
# Processing Record 49 of Set 8 | baykit
# Processing Record 50 of Set 8 | maniitsoq
# Processing Record 1 of Set 9 | hanzhong
# City not found. Skipping...
# Processing Record 2 of Set 9 | korla
# Processing Record 3 of Set 9 | antalaha
# Processing Record 4 of Set 9 | hokitika
# Processing Record 5 of Set 9 | hueyapan
# City not found. Skipping...
# Processing Record 6 of Set 9 | khandbari
# City not found. Skipping...
# Processing Record 7 of Set 9 | palauig
# Processing Record 8 of Set 9 | avera
# Processing Record 9 of Set 9 | wajima
# Processing Record 10 of Set 9 | jieshi
# Processing Record 11 of Set 9 | huarmey
# Processing Record 12 of Set 9 | piacabucu
# Processing Record 13 of Set 9 | mao
# Processing Record 14 of Set 9 | berdigestyakh
# Processing Record 15 of Set 9 | bedele
# Processing Record 16 of Set 9 | rio gallegos
# Processing Record 17 of Set 9 | ola
# Processing Record 18 of Set 9 | saint anthony
# Processing Record 19 of Set 9 | shubarshi
# Processing Record 20 of Set 9 | great yarmouth
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | balclutha
# Processing Record 24 of Set 9 | caxito
# Processing Record 25 of Set 9 | bambous virieux
# Processing Record 26 of Set 9 | nautla
# Processing Record 27 of Set 9 | iralaya
# Processing Record 28 of Set 9 | liwale
# Processing Record 29 of Set 9 | havelock
# Processing Record 30 of Set 9 | kawalu
# City not found. Skipping...
# Processing Record 31 of Set 9 | scarborough
# Processing Record 32 of Set 9 | along
# Processing Record 33 of Set 9 | porbandar
# City not found. Skipping...
# Processing Record 34 of Set 9 | san jeronimo
# Processing Record 35 of Set 9 | moose factory
# Processing Record 36 of Set 9 | aklavik
# Processing Record 37 of Set 9 | alofi
# Processing Record 38 of Set 9 | kismayo
# Processing Record 39 of Set 9 | marsh harbour
# Processing Record 40 of Set 9 | rach gia
# Processing Record 41 of Set 9 | tefe
# Processing Record 42 of Set 9 | quelimane
# Processing Record 43 of Set 9 | arman
# Processing Record 44 of Set 9 | tolu
# Processing Record 45 of Set 9 | gambela
# Processing Record 46 of Set 9 | scottsbluff
# Processing Record 47 of Set 9 | malysheva
# Processing Record 48 of Set 9 | tiznit
# Processing Record 49 of Set 9 | jabinyanah
# Processing Record 50 of Set 9 | marzuq
# Processing Record 1 of Set 10 | meulaboh
# City not found. Skipping...
# Processing Record 2 of Set 10 | darnah
# Processing Record 3 of Set 10 | misratah
# Processing Record 4 of Set 10 | pisco
# Processing Record 5 of Set 10 | santa maria
# Processing Record 6 of Set 10 | aranos
# Processing Record 7 of Set 10 | rawson
# Processing Record 8 of Set 10 | ancud
# Processing Record 9 of Set 10 | ambilobe
# Processing Record 10 of Set 10 | lazaro cardenas
# Processing Record 11 of Set 10 | turochak
# Processing Record 12 of Set 10 | playa vicente
# Processing Record 13 of Set 10 | san matias
# Processing Record 14 of Set 10 | hasaki
# City not found. Skipping...
# Processing Record 15 of Set 10 | yabrud
# Processing Record 16 of Set 10 | yongchang
# Processing Record 17 of Set 10 | samarai
# Processing Record 18 of Set 10 | chabahar
# Processing Record 19 of Set 10 | east angus
# City not found. Skipping...
# Processing Record 20 of Set 10 | tahoua
# Processing Record 21 of Set 10 | guerrero negro
# Processing Record 22 of Set 10 | kuandian
# Processing Record 23 of Set 10 | dunedin
# Processing Record 24 of Set 10 | peschanokopskoye
# Processing Record 25 of Set 10 | sisimiut
# Processing Record 26 of Set 10 | tommot
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | hindoria
# Processing Record 29 of Set 10 | playas
# Processing Record 30 of Set 10 | palmas
# Processing Record 31 of Set 10 | raga
# Processing Record 32 of Set 10 | gidole
# Processing Record 33 of Set 10 | san luis
# Processing Record 34 of Set 10 | ginir
# Processing Record 35 of Set 10 | catamarca
# Processing Record 36 of Set 10 | caronport
# Processing Record 37 of Set 10 | magdug
# Processing Record 38 of Set 10 | grootfontein
# Processing Record 39 of Set 10 | luau
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | inuvik
# Processing Record 42 of Set 10 | martapura
# Processing Record 43 of Set 10 | meadow lake
# Processing Record 44 of Set 10 | teguise
# Processing Record 45 of Set 10 | carinhanha
# Processing Record 46 of Set 10 | oriximina
# Processing Record 47 of Set 10 | muroto
# Processing Record 48 of Set 10 | pran buri
# Processing Record 49 of Set 10 | manicore
# City not found. Skipping...
# Processing Record 50 of Set 10 | eureka
# Processing Record 1 of Set 11 | shelburne
# City not found. Skipping...
# Processing Record 2 of Set 11 | manadhoo
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | ponta delgada
# Processing Record 5 of Set 11 | miri
# Processing Record 6 of Set 11 | luang prabang
# Processing Record 7 of Set 11 | buritis
# Processing Record 8 of Set 11 | krasnoturansk
# Processing Record 9 of Set 11 | hjorring
# Processing Record 10 of Set 11 | aksarka
# Processing Record 11 of Set 11 | bagaciu
# City not found. Skipping...
# Processing Record 12 of Set 11 | phalaborwa
# Processing Record 13 of Set 11 | barranquilla
# Processing Record 14 of Set 11 | mairana
# Processing Record 15 of Set 11 | mahon
# Processing Record 16 of Set 11 | aviemore
# Processing Record 17 of Set 11 | richards bay
# Processing Record 18 of Set 11 | talnakh
# Processing Record 19 of Set 11 | obo
# Processing Record 20 of Set 11 | burnie
# Processing Record 21 of Set 11 | lima
# Processing Record 22 of Set 11 | sakaiminato
# Processing Record 23 of Set 11 | boca del monte
# Processing Record 24 of Set 11 | adeje
# Processing Record 25 of Set 11 | thomasville
# Processing Record 26 of Set 11 | roma
# Processing Record 27 of Set 11 | kieta
# Processing Record 28 of Set 11 | sergeyevka
# Processing Record 29 of Set 11 | puerto cabezas
# City not found. Skipping...
# Processing Record 30 of Set 11 | ratnagiri
# Processing Record 31 of Set 11 | seguela
# Processing Record 32 of Set 11 | jasper
# Processing Record 33 of Set 11 | daru
# Processing Record 34 of Set 11 | gat
# Processing Record 35 of Set 11 | vestmannaeyjar
# Processing Record 36 of Set 11 | gourcy
# Processing Record 37 of Set 11 | aitape
# Processing Record 38 of Set 11 | okhotsk
# Processing Record 39 of Set 11 | san felipe
# Processing Record 40 of Set 11 | laguna
# Processing Record 41 of Set 11 | rosarito
# Processing Record 42 of Set 11 | maunabo
# Processing Record 43 of Set 11 | aswan
# Processing Record 44 of Set 11 | dingli
# Processing Record 45 of Set 11 | broome
# Processing Record 46 of Set 11 | kangaatsiaq
# Processing Record 47 of Set 11 | beringovskiy
# City not found. Skipping...
# Processing Record 48 of Set 11 | otavi
# Processing Record 49 of Set 11 | sorong
# Processing Record 50 of Set 11 | isangel
# Processing Record 1 of Set 12 | sri aman
# Processing Record 2 of Set 12 | ormara
# Processing Record 3 of Set 12 | deputatskiy
# City not found. Skipping...
# Processing Record 4 of Set 12 | benghazi
# Processing Record 5 of Set 12 | tarbagatay
# Processing Record 6 of Set 12 | yulara
# Processing Record 7 of Set 12 | tiarei
# Processing Record 8 of Set 12 | woodward
# Processing Record 9 of Set 12 | krasnogorsk
# Processing Record 10 of Set 12 | cuamba

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Put collected data into a dataframe
city_df = pd.DataFrame({"City": name, "Latitude": lat, "Longitude": lng, "Max Temp": max_temp, "Humidity": humidity,
                       "Cloudiness": cloudiness, "Wind Speed": wind_speed, "Country": country, "Date": date})

#Export data to csv
city_df.to_csv("output_files/city.csv")

city_df.head()
# Out:
#                 City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0            Hualmay  -11.0964   -77.6139    294.28        81          99
# 1  Saint Paul Harbor   57.7900  -152.4072    272.15        64           1
# 2      Srednekolymsk   67.4500   153.6833    243.34        86         100
# 3        Tuktoyaktuk   69.4541  -133.0374    240.15        75          20
# 4          Jamestown   42.0970   -79.2353    270.37        80          90
#
#    Wind Speed Country        Date
# 0        4.47      PE  1612149962
# 1        2.57      US  1612149962
# 2        3.61      RU  1612149668
# 3        1.54      CA  1612149962
# 4        3.60      US  1612149962

# %%
too_humid = city_df["Humidity"].loc[city_df["Humidity"]>100]
print(too_humid)
# Out:
# Series([], Name: Humidity, dtype: int64)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
too_humid = city_df["Humidity"].loc[city_df["Humidity"]>100]
# print(too_humid["index"])
print(too_humid)
# Out:
# Series([], Name: Humidity, dtype: int64)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Max Temperature ({date_convert})')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
date_time = time.gmtime(city_df['Date'][0])
date_convert = time.strftime("%x", date_time)

# Build a scatter plot for each data type
plt.scatter(city_df["Latitude"], city_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Humidity ({date_convert})')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_files/fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
